# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('bhavdata.csv')
df
# Out:
#       INSTRUMENT     SYMBOL    EXPIRY_DT  STRIKE_PR OPTION_TYP      OPEN  \
# 0         FUTIDX  BANKNIFTY  27-Aug-2020        0.0         XX  21851.00
# 1         FUTIDX  BANKNIFTY  24-Sep-2020        0.0         XX  21888.75
# 2         FUTIDX  BANKNIFTY  29-Oct-2020        0.0         XX  21899.95
# 3         FUTIDX      NIFTY  27-Aug-2020        0.0         XX  11274.95
# 4         FUTIDX      NIFTY  24-Sep-2020        0.0         XX  11262.00
# ...          ...        ...          ...        ...        ...       ...
# 34845     OPTSTK       ZEEL  29-Oct-2020      190.0         PE      0.00
# 34846     OPTSTK       ZEEL  29-Oct-2020      195.0         PE      0.00
# 34847     OPTSTK       ZEEL  29-Oct-2020      200.0         PE      0.00
# 34848     OPTSTK       ZEEL  29-Oct-2020      205.0         PE      0.00
# 34849     OPTSTK       ZEEL  29-Oct-2020      210.0         PE      0.00
#
#            HIGH       LOW     CLOSE  SETTLE_PR  CONTRACTS  VAL_INLAKH  \
# ...

# %%
df.shape
# Out:
# (34850, 16)

# %%
df1 = df[df['INSTRUMENT'].str.contains('OPTSTK')]
df1
# Out:
#       INSTRUMENT SYMBOL    EXPIRY_DT  STRIKE_PR OPTION_TYP  OPEN  HIGH  LOW  \
# 4180      OPTSTK    ACC  27-Aug-2020      800.0         CE   0.0   0.0  0.0
# 4181      OPTSTK    ACC  27-Aug-2020      820.0         CE   0.0   0.0  0.0
# 4182      OPTSTK    ACC  27-Aug-2020      840.0         CE   0.0   0.0  0.0
# 4183      OPTSTK    ACC  27-Aug-2020      860.0         CE   0.0   0.0  0.0
# 4184      OPTSTK    ACC  27-Aug-2020      880.0         CE   0.0   0.0  0.0
# ...          ...    ...          ...        ...        ...   ...   ...  ...
# 34845     OPTSTK   ZEEL  29-Oct-2020      190.0         PE   0.0   0.0  0.0
# 34846     OPTSTK   ZEEL  29-Oct-2020      195.0         PE   0.0   0.0  0.0
# 34847     OPTSTK   ZEEL  29-Oct-2020      200.0         PE   0.0   0.0  0.0
# 34848     OPTSTK   ZEEL  29-Oct-2020      205.0         PE   0.0   0.0  0.0
# 34849     OPTSTK   ZEEL  29-Oct-2020      210.0         PE   0.0   0.0  0.0
#
# ...

# %%
multisymbols = [
    'ACC',
    'ADANIENT',
    'ADANIPORTS',
    'AMARAJABAT',
    'AMBUJACEM',
    'APOLLOHOSP',
    'APOLLOTYRE',
    'ASHOKLEY',
    'ASIANPAINT',
    'AUROPHARMA',
    'AXISBANK',
    'BAJAJ-AUTO',
    'BAJAJFINSV',
    'BAJFINANCE',
    'BALKRISIND',
    'BANDHANBNK',
    'BANKBARODA',
    'BATAINDIA',
    'BEL',
    'BERGEPAINT',
    'BHARATFORG',
    'BHARTIARTL',
    'BHEL',
    'BIOCON',
    'BOSCHLTD',
    'BPCL',
    'BRITANNIA',
    'CADILAHC',
    'CANBK',
    'CENTURYTEX',
    'CHOLAFIN',
    'CIPLA',
    'COALINDIA',
    'COLPAL',
    'CONCOR',
    'CUMMINSIND',
    'DABUR',
    'DIVISLAB',
    'DLF',
    'DRREDDY',
    'EICHERMOT',
    'EQUITAS',
    'ESCORTS',
    'EXIDEIND',
    'FEDERALBNK',
    'GAIL',
    'GLENMARK',
    'GMRINFRA',
    'GODREJCP',
    'GODREJPROP',
    'GRASIM',
    'HAVELLS',
    'HCLTECH',
    'HDFC',
    'HDFCBANK',
    'HDFCLIFE',
    'HEROMOTOCO',
    'HINDALCO',
    'HINDPETRO',
    'HINDUNILVR',
    'IBULHSGFIN',
    'ICICIBANK',
    'ICICIPRULI',
    'IDEA',
    'IDFCFIRSTB',
    'IGL',
    'INDIGO',
    'INDUSINDBK',
    'INFRATEL',
    'INFY',
    'IOC',
    'ITC',
    'JINDALSTEL',
    'JSWSTEEL',
    'JUBLFOOD',
    'KOTAKBANK',
    'L&TFH',
    'LICHSGFIN',
    'LT',
    'LUPIN',
    'M&M',
    'M&MFIN',
    'MANAPPURAM',
    'MARICO',
    'MARUTI',
    'MCDOWELL-N',
    'MFSL',
    'MGL',
    'MINDTREE',
    'MOTHERSUMI',
    'MRF',
    'MUTHOOTFIN',
    'NATIONALUM',
    'NAUKRI',
    'NESTLEIND',
    'NIITTECH',
    'NMDC',
    'NTPC',
    'ONGC',
    'PAGEIND',
    'PEL',
    'PETRONET',
    'PFC',
    'PIDILITIND',
    'PNB',
    'POWERGRID',
    'PVR',
    'RAMCOCEM',
    'RBLBANK',
    'RECLTD',
    'RELIANCE',
    'SAIL',
    'SBILIFE',
    'SBIN',
    'SHREECEM',
    'SEIMENS',
    'SRF',
    'SRTRANSFIN',
    'SUNPHARMA',
    'SUNTV',
    'TATACHEM',
    'TATACONSUM',
    'TATAMOTORS',
    'TATAPOWER',
    'TATASTEEL',
    'TCS',
    'TECHM',
    'TITAN',
    'TORNTPHARM',
    'TORNTPOWER',
    'TVSMOTOR',
    'UBL',
    'UJJIVAN',
    'ULTRACEMCO',
    'UPL',
    'VEDL',
    'VOLTAS',
    'WIPRO',
    'ZEEL' 
    ]
df2 = df1[df['SYMBOL'].isin(multisymbols)]
df2
# Out:
# <ipython-input-5-a3f2579ea4a1>:142: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df2 = df1[df['SYMBOL'].isin(multisymbols)]
#       INSTRUMENT SYMBOL    EXPIRY_DT  STRIKE_PR OPTION_TYP  OPEN  HIGH  LOW  \
# 4180      OPTSTK    ACC  27-Aug-2020      800.0         CE   0.0   0.0  0.0
# 4181      OPTSTK    ACC  27-Aug-2020      820.0         CE   0.0   0.0  0.0
# 4182      OPTSTK    ACC  27-Aug-2020      840.0         CE   0.0   0.0  0.0
# 4183      OPTSTK    ACC  27-Aug-2020      860.0         CE   0.0   0.0  0.0
# 4184      OPTSTK    ACC  27-Aug-2020      880.0         CE   0.0   0.0  0.0
# ...          ...    ...          ...        ...        ...   ...   ...  ...
# 34845     OPTSTK   ZEEL  29-Oct-2020      190.0         PE   0.0   0.0  0.0
# 34846     OPTSTK   ZEEL  29-Oct-2020      195.0         PE   0.0   0.0  0.0
# 34847     OPTSTK   ZEEL  29-Oct-2020      200.0         PE   0.0   0.0  0.0
# ...

# %%
#Change according to liking
#Get a single date or a specific date
dates = ["27-Aug-2020"] 
df3 = df2[df['EXPIRY_DT'].isin(dates)]
df3
# Out:
# <ipython-input-6-92cf25ff67a9>:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df3 = df2[df['EXPIRY_DT'].isin(dates)]
#       INSTRUMENT SYMBOL    EXPIRY_DT  STRIKE_PR OPTION_TYP  OPEN  HIGH  LOW  \
# 4180      OPTSTK    ACC  27-Aug-2020      800.0         CE   0.0   0.0  0.0
# 4181      OPTSTK    ACC  27-Aug-2020      820.0         CE   0.0   0.0  0.0
# 4182      OPTSTK    ACC  27-Aug-2020      840.0         CE   0.0   0.0  0.0
# 4183      OPTSTK    ACC  27-Aug-2020      860.0         CE   0.0   0.0  0.0
# 4184      OPTSTK    ACC  27-Aug-2020      880.0         CE   0.0   0.0  0.0
# ...          ...    ...          ...        ...        ...   ...   ...  ...
# 34741     OPTSTK   ZEEL  27-Aug-2020      220.0         PE   0.0   0.0  0.0
# 34742     OPTSTK   ZEEL  27-Aug-2020      225.0         PE   0.0   0.0  0.0
# 34743     OPTSTK   ZEEL  27-Aug-2020      230.0         PE   0.0   0.0  0.0
# ...

# %%
#Filters out all the Values of only PE
df4 = df3[df['OPTION_TYP'].str.contains("PE")]
df4
# Out:
# <ipython-input-7-67b23108180e>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df4 = df3[df['OPTION_TYP'].str.contains("PE")]
#       INSTRUMENT SYMBOL    EXPIRY_DT  STRIKE_PR OPTION_TYP  OPEN  HIGH  LOW  \
# 4225      OPTSTK    ACC  27-Aug-2020      800.0         PE   0.0   0.0  0.0
# 4226      OPTSTK    ACC  27-Aug-2020      820.0         PE   0.0   0.0  0.0
# 4227      OPTSTK    ACC  27-Aug-2020      840.0         PE   0.0   0.0  0.0
# 4228      OPTSTK    ACC  27-Aug-2020      860.0         PE   0.0   0.0  0.0
# 4229      OPTSTK    ACC  27-Aug-2020      880.0         PE   0.0   0.0  0.0
# ...          ...    ...          ...        ...        ...   ...   ...  ...
# 34741     OPTSTK   ZEEL  27-Aug-2020      220.0         PE   0.0   0.0  0.0
# 34742     OPTSTK   ZEEL  27-Aug-2020      225.0         PE   0.0   0.0  0.0
# 34743     OPTSTK   ZEEL  27-Aug-2020      230.0         PE   0.0   0.0  0.0
# ...

# %%
aggregation_dict = {col: 'first' for col in df4.columns}
aggregation_dict['CHG_IN_OI'] = 'max'
df4 = df4.groupby(['SYMBOL'], as_index=True).agg(aggregation_dict)
df4
# Out:
#            INSTRUMENT      SYMBOL    EXPIRY_DT  STRIKE_PR OPTION_TYP  OPEN  \
# SYMBOL
# ACC            OPTSTK         ACC  27-Aug-2020      800.0         PE  0.00
# ADANIENT       OPTSTK    ADANIENT  27-Aug-2020       82.5         PE  0.00
# ADANIPORTS     OPTSTK  ADANIPORTS  27-Aug-2020      210.0         PE  0.00
# AMARAJABAT     OPTSTK  AMARAJABAT  27-Aug-2020      370.0         PE  0.00
# AMBUJACEM      OPTSTK   AMBUJACEM  27-Aug-2020      132.5         PE  0.00
# ...               ...         ...          ...        ...        ...   ...
# UPL            OPTSTK         UPL  27-Aug-2020      240.0         PE  0.00
# VEDL           OPTSTK        VEDL  27-Aug-2020       55.0         PE  0.00
# VOLTAS         OPTSTK      VOLTAS  27-Aug-2020      340.0         PE  0.00
# WIPRO          OPTSTK       WIPRO  27-Aug-2020      140.0         PE  0.00
# ZEEL           OPTSTK        ZEEL  27-Aug-2020      100.0         PE  0.35
#
# ...

# %%
df4.shape
# Out:
# (138, 16)

# %%
df4.to_csv('OPTSTK_PE_Stocks.csv')
